# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.90)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import cv2
from google.colab.patches import cv2_imshow

# Read the RGB image
image = cv2.imread("Iron Man.png")

# Convert RGB image to Grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display original and grayscale images
cv2_imshow(image)
cv2_imshow(gray_image)

# Save grayscale image
cv2.imwrite("Iron Man.png", gray_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=697x387>
# <PIL.Image.Image image mode=L size=697x387>
